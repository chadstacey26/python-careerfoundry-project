# %% [markdown]
# # 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing data

# %%
# Create string from project folder path 
path = r'/Users/chadstacey/04-01-2021_InstaCart_Basket_Analysis'

# %%
# Create list 
vars_list = ['order_id', 'user_id', 'order_number', 'orders_day_of_week', 'order_hour_of_day', 'days_since_prior_order']

# %%
# Import orders.csv
df_ords = pd.read_csv(os.path.join(path, '02_Data', 'Prepared_Data', 'orders_cleaned.csv'), usecols = vars_list)

# %%
# Import df_ords_prior.csv
df_ords_prior = pd.read_csv(os.path.join(path, '02_Data', 'Original_Data', 'order_products__prior.csv'), index_col = False)

# %% [markdown]
# # 03. Checking output and shape

# %%
# Check the output
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Check the output
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# Check shape
df_ords.shape
# Out:
# (3421083, 6)

# %%
# Check shape
df_ords_prior.shape
# Out:
# (32434489, 4)

# %% [markdown]
# # 04. Merging the data

# %%
# Merge df_ords and df_ords_prior
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id')

# %%
# Check output
df_merged_large.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0

# %%
# Test without overwriting
pd.merge(df_ords_prior,df_ords, on = ['order_id'], indicator = True)
# Out:
#           order_id  product_id  add_to_cart_order  reordered  user_id  \
# 0                2       33120                  1          1   202279
# 1                2       28985                  2          1   202279
# 2                2        9327                  3          0   202279
# 3                2       45918                  4          1   202279
# 4                2       30035                  5          0   202279
# ...            ...         ...                ...        ...      ...
# 32434484   3421083       39678                  6          1    25247
# 32434485   3421083       11352                  7          0    25247
# 32434486   3421083        4600                  8          0    25247
# 32434487   3421083       24852                  9          1    25247
# 32434488   3421083        5020                 10          1    25247
#
#           order_number  orders_day_of_week  order_hour_of_day  \
# 0                    3                   5                  9
# ...

# %%
# Export data to pkl
df_merged_large.to_pickle(os.path.join(path, '02_Data','Prepared_Data', 'orders_products_combined.pkl'))
